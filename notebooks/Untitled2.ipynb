# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import logging
import os

from rec_to_binaries import extract_trodes_rec_file

SPIKE_GADGETS_PATH = os.path.join(os.path.expanduser('~'), 'SpikeGadgets')

os.environ['PATH'] += os.pathsep + SPIKE_GADGETS_PATH

print(os.environ['PATH'])
# Out:
# /home/edeno/bin:/home/edeno/.local/bin:/home/edeno/bin:/home/edeno/.local/bin:/home/edeno/miniconda3/envs/rec_to_binaries/bin:/home/edeno/miniconda3/condabin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin:/home/edeno/SpikeGadgets

# %%
import rec_to_binaries.trodes_data as td

data_dir = os.path.abspath(os.path.join(os.pardir, 'test_data'))
animal = 'lotus'

animal_info = td.TrodesAnimalInfo(data_dir, animal)

extractor = td.ExtractRawTrodesData(animal_info)
raw_epochs_unionset = animal_info.get_raw_epochs_unionset()

# %%
animal_info.get_raw_dates()
# Out:
# ['20190902']

# %%
animal_info.

# %%
animal_info.get_raw_dates()
# Out:
# ['20190902']

# %%
raw_epochs_unionset
# Out:
# {6}

# %%
logging.basicConfig(level='INFO', format='%(asctime)s %(message)s',
                    datefmt='%d-%b-%y %H:%M:%S')

data_dir = os.path.abspath(os.path.join(os.pardir, 'test_data'))
animal = 'lotus'

extract_trodes_rec_file(
    data_dir,
    animal,
    parallel_instances=4,
    overwrite=True,
    extract_analog=False,
    extract_spikes=False,
    extract_lfps=False,
    extract_dio=False,
    extract_time=True,
    extract_mda=False)
# Out:
# 07-Aug-20 12:04:32 Extracting time...
# (ID: 0) Running exporttime on animal lotus date 20190902 epoch 06
# (ID: 0) Full command: ['exporttime', '-rec', '/home/edeno/Documents/Github/rec_to_binaries/test_data/lotus/raw/20190902/20190902_lotus_06_r3.rec', '-outputdirectory', '/home/edeno/Documents/Github/rec_to_binaries/test_data/lotus/preprocessing/20190902', '-output', '20190902_lotus_06_r3']
# (ID: 0) Done running ['exporttime', '-rec', '/home/edeno/Documents/Github/rec_to_binaries/test_data/lotus/raw/20190902/20190902_lotus_06_r3.rec', '-outputdirectory', '/home/edeno/Documents/Github/rec_to_binaries/test_data/lotus/preprocessing/20190902', '-output', '20190902_lotus_06_r3']
# (ID: 0) Exporting continuous time period data...
# (ID: 0) File contains system clock information.
# (ID: 0) 0 %
# (ID: 0) 5 %
# (ID: 0) 10 %
# (ID: 0) 15 %
# (ID: 0) 20 %
# (ID: 0) 25 %
# (ID: 0) 30 %
# (ID: 0) 35 %
# (ID: 0) 40 %
# (ID: 0) 45 %
# (ID: 0) 50 %
# (ID: 0) 55 %
# (ID: 0) 60 %
# (ID: 0) 65 %
# ...

# %%
logging.basicConfig(level='INFO', format='%(asctime)s %(message)s',
                    datefmt='%d-%b-%y %H:%M:%S')

data_dir = "/data2/data1_backup/jason/"
animal = 'kf2'

extract_trodes_rec_file(data_dir, animal, parallel_instances=4, overwrite=True)
# Out:
# /home/edeno/Documents/Github/rec_to_binaries/rec_to_binaries/trodes_data.py:602: TrodesDataFormatWarning: animal path (/data2/data1_backup/jason/kf2/raw) contains a data directory (20161108_test) that does not conform to date format %Y%m%d.
#   format(anim_path, anim_dir_entry.name), TrodesDataFormatWarning)
# /home/edeno/Documents/Github/rec_to_binaries/rec_to_binaries/trodes_data.py:626: TrodesDataFormatWarning: Invalid trodes rec filename (/data2/data1_backup/jason/kf2/raw/20161106/20161106_KF2_r2.rec), cannot be parsed, skipping.
#   format(dir_entry.path), TrodesDataFormatWarning)
# /home/edeno/Documents/Github/rec_to_binaries/rec_to_binaries/trodes_data.py:626: TrodesDataFormatWarning: Invalid trodes rec filename (/data2/data1_backup/jason/kf2/raw/20161106/20161106_KF2_r1.rec), cannot be parsed, skipping.
#   format(dir_entry.path), TrodesDataFormatWarning)
# ...

# %%
exporttime -rec /data2/data1_backup/jason/kf2/raw/20170120/20170120_KF2_01_s1.rec -outputdirectory /home/edeno/Documents/Github/rec_to_binaries/test_data -output 20170120_KF2_01_s1 -reconfig /data2/data1_backup/jason/kf2/raw/20170120/20170216_kibbles_reconfig2.xml
# Out:
#   File "<ipython-input-4-532d72ecaed6>", line 1
#     exporttime -rec /data2/data1_backup/jason/kf2/raw/20170120/20170120_KF2_01_s1.rec -outputdirectory /home/edeno/Documents/Github/rec_to_binaries/test_data -output 20170120_KF2_01_s1 -reconfig /data2/data1_backup/jason/kf2/raw/20170120/20170216_kibbles_reconfig2.xml
#                                                                        ^
# SyntaxError: invalid token
